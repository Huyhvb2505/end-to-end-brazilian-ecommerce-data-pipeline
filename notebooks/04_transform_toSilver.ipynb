# %%
##1 . Data cleaning and validation

# %%
#1. Check duplicate

# %%
df_customers = spark.read.csv()
df_customers = 
df_customers = 
df_customers = 
df_customers = 
df_customers = 
df_customers = 
df_customers = 
df_customers =
